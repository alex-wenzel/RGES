# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

import json

# %%
PYTHON_RES_PATH = "/home/jovyan/oncogxA/Alex/l1k/LINCS_FULL_GEO_RANKED/LINCS_landmarks_python_scores.json"
R_RES_PATH = "/home/jovyan/oncogxA/Alex/l1k/LINCS_FULL_GEO_RANKED/chen_pipeline_scores.tsv"

PYTHON_RES = json.loads(open(PYTHON_RES_PATH).read())
R_RES = pd.read_csv(R_RES_PATH, sep='\t')

# %%
points = []

for _, row in R_RES.iterrows():
    points.append((row['score'], PYTHON_RES[row['profile']]))

# %%
x = [p[0] for p in points]
y = [p[1] for p in points]

plt.scatter(x, y)
plt.xlabel("R")
plt.ylabel("Python")
